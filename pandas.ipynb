# %% [markdown]
# # Pandas
#
# - Pandas is a powerful python data analysis toolkit.
# - Open source
# - A fast and efficient Dataframe object for data manipulation.
# - Reading and writing data structures and different formats: csv,tsv,txt,xml,json,zip,etc.
# - Pandas can read three types of data structure-Series,Dataframe,Panel.
# - Installation of pandas- pip install pandas.
# - importing panda library-> import pandas as pd

# %% [markdown]
# ### Pandas series

# %%
import pandas as pd
pd.__version__ ## just to check the version
# Out:
# '2.2.1'

# %%
list =[1,2,3,4,'Datavalues']
print(list)
# Out:
# [1, 2, 3, 4, 'Datavalues']

# %%
ser = pd.Series(list)
print(ser)
# Out:
# 0             1
# 1             2
# 2             3
# 3             4
# 4    Datavalues
# dtype: object

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
ser_2 = pd.Series([1,2,3,4])
print(ser_2)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
empty = pd.Series([]) ## Creating empty series
print(empty)
# Out:
# Series([], dtype: object)

# %%
ser3 = pd.Series([1,2,3,4],index =['a','b','c','d'])
print(ser3)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
ser4 = pd.Series([1,2,3,4],index =['a','b','c','d'], dtype = float)
print(ser4)
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# dtype: float64

# %%
ser5 = pd.Series([1,2,3,4],index =['a','b','c','d'], dtype = float, name='data values')
print(ser5)
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# Name: data values, dtype: float64

# %%
scalar_s =pd.Series(0.5)
print(scalar_s)
# Out:
# 0    0.5
# dtype: float64

# %%
scalar_s =pd.Series(0.5, index=[1,2,3])
print(scalar_s)
# Out:
# 1    0.5
# 2    0.5
# 3    0.5
# dtype: float64

# %%
dist = pd.Series({'a':1,'b':2,'c':3,'d':4})
dist
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
ser4 = pd.Series([1,2,3,4,5])
print(ser4)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
ser4[0]
# Out:
# 1

# %%
ser4[3]
# Out:
# 4

# %%
ser4[4]
# Out:
# 5

# %%
ser4[0:3]
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
max(ser4)
# Out:
# 5

# %%
min(ser4)
# Out:
# 1

# %%
ser4[ser4>3]
# Out:
# 3    4
# 4    5
# dtype: int64

# %%
ser5=pd.Series([6,7,8,9,10])
ser5
# Out:
# 0     6
# 1     7
# 2     8
# 3     9
# 4    10
# dtype: int64

# %%
ser4 + ser5
# Out:
# 0     7
# 1     9
# 2    11
# 3    13
# 4    15
# dtype: int64

# %% [markdown]
# # Dataframe
#
# - Pandas dataframe is 2D, size-mutable, potentially heteroogeneous tabular data structure with    labeled axes(rows and columns).

# %%
import pandas as pd

# %%
empt_df = pd.DataFrame()
print(empt_df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
## Creating dataframe from the list
lst=['a','b','c']
print(lst)
# Out:
# ['a', 'b', 'c']

# %%
df1 = pd.DataFrame(lst)
print(df1)
# Out:
#    0
# 0  a
# 1  b
# 2  c

# %%
df1
# Out:
#    0
# 0  a
# 1  b
# 2  c

# %%
ls_of_ls =[[1,2,3],[4,5,6],[7,8,9]]
print(ls_of_ls)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
df2 = pd.DataFrame(ls_of_ls)
df2
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
## Creating dataframe from the dictionary
dict1= {'ID': [11,22,33,44]}
dict1
# Out:
# {'ID': [11, 22, 33, 44]}

# %%
df3 = pd.DataFrame(dict1)
df3
# Out:
#    ID
# 0  11
# 1  22
# 2  33
# 3  44

# %%
dict1= {'ID': [11,22,33,44],'SN':[120,340,53,110]}
dict1
# Out:
# {'ID': [11, 22, 33, 44], 'SN': [120, 340, 53, 110]}

# %%
df3 = pd.DataFrame(dict1)
df3
# Out:
#    ID   SN
# 0  11  120
# 1  22  340
# 2  33   53
# 3  44  110

# %%
## Creating pandas dataframe from list of dictionaries.
ls_dict = [{'a':1,'b':2},{'a':3,'b':4,'c':5}]
df5=pd.DataFrame(ls_dict)
df5
# Out:
#    a  b    c
# 0  1  2  NaN
# 1  3  4  5.0

# %%
dict_sr = {'Id': pd.Series([1,2,3]), 'SN':[111,222,333]}
df6 = pd.DataFrame(dict_sr)
df6
# Out:
#    Id   SN
# 0   1  111
# 1   2  222
# 2   3  333

# %% [markdown]
# ## Read CSV File and  Write csv file
#
# - Comma separated values
# - Advantages:- Universal, Easy to understand, Quick to create.

# %%
import pandas as pd

# %%
## help(pd.read_csv)
y1= pd.read_csv('blood1.csv')
y1.head()
# Out:
#    Unnamed: 0                 0                  1                      2  \
# 0           0  Recency (months)  Frequency (times)  Monetary (c.c. blood)
# 1           1                 2                 50                    NaN
# 2           2                 0                 13                   3250
# 3           3               NaN                 16                   4000
# 4           4               NaN                 20                   5000
#
#                3                                           4
# 0  Time (months)  whether he/she donated blood in March 2007
# 1             98                                           1
# 2             28                                           1
# 3             35                                           1
# 4             45                                           1

# %%
import os

# %%
print(os.getcwd())
# Out:
# D:\jupyter\python libraries

# %%
type(y1)
# Out:
# pandas.core.frame.DataFrame

# %%
y1= pd.read_csv('blood1.csv', nrows=4, usecols=[0,1])
y1.head()
# Out:
#    Unnamed: 0                 0
# 0           0  Recency (months)
# 1           1                 2
# 2           2                 0
# 3           3               NaN

# %%
y2=pd.read_csv('blood1.csv',  skiprows=[0], index_col=[0])
y2.head()
# Out:
#    Recency (months)  Frequency (times)  Monetary (c.c. blood)  Time (months)  \
# 0
# 1               2.0                 50                    NaN             98
# 2               0.0                 13                 3250.0             28
# 3               NaN                 16                 4000.0             35
# 4               NaN                 20                 5000.0             45
# 5               1.0                 24                 6000.0             77
#
#    whether he/she donated blood in March 2007
# 0
# 1                                           1
# 2                                           1
# 3                                           1
# 4                                           1
# 5                                           0

# %%
y2=pd.read_csv('blood1.csv',header=None)
y2.head()
# Out:
#      0                 1                  2                      3  \
# 0  NaN                 0                  1                      2
# 1  0.0  Recency (months)  Frequency (times)  Monetary (c.c. blood)
# 2  1.0                 2                 50                    NaN
# 3  2.0                 0                 13                   3250
# 4  3.0               NaN                 16                   4000
#
#                4                                           5
# 0              3                                           4
# 1  Time (months)  whether he/she donated blood in March 2007
# 2             98                                           1
# 3             28                                           1
# 4             35                                           1

# %%
y2=pd.read_csv('blood1.csv', names= ['one','two','three','four','five'])
y2.head()
# Out:
#                   one                two                  three  \
# NaN                 0                  1                      2
# 0.0  Recency (months)  Frequency (times)  Monetary (c.c. blood)
# 1.0                 2                 50                    NaN
# 2.0                 0                 13                   3250
# 3.0               NaN                 16                   4000
#
#               four                                        five
# NaN              3                                           4
# 0.0  Time (months)  whether he/she donated blood in March 2007
# 1.0             98                                           1
# 2.0             28                                           1
# 3.0             35                                           1

# %%
y2.head(4)
# Out:
#                   one                two                  three  \
# NaN                 0                  1                      2
# 0.0  Recency (months)  Frequency (times)  Monetary (c.c. blood)
# 1.0                 2                 50                    NaN
# 2.0                 0                 13                   3250
#
#               four                                        five
# NaN              3                                           4
# 0.0  Time (months)  whether he/she donated blood in March 2007
# 1.0             98                                           1
# 2.0             28                                           1

# %%
y2.tail(4)
# Out:
#       one two three four five
# 745.0  21   2   500   52    0
# 746.0  23   3   750   62    0
# 747.0  39   1   250   39    0
# 748.0  72   1   250   72    0

# %% [markdown]
# ## Handling missing Values

# %%
import pandas as pd

# %%
df= pd.read_csv('blood1.csv', na_values=None, keep_default_na=False)
df.head()
#keep_default_na shows the false or true in place of nan value.
# Out:
#    Unnamed: 0                 0                  1                      2  \
# 0           0  Recency (months)  Frequency (times)  Monetary (c.c. blood)
# 1           1                 2                 50
# 2           2                 0                 13                   3250
# 3           3                                   16                   4000
# 4           4                                   20                   5000
#
#                3                                           4
# 0  Time (months)  whether he/she donated blood in March 2007
# 1             98                                           1
# 2             28                                           1
# 3             35                                           1
# 4             45                                           1

# %%
df= pd.read_csv('blood1.csv', na_values=None,skiprows=1)

# %% [markdown]
# #### isnull or notnull

# %%
## isnull and notnull
df.isnull()
# Out:
#          0  Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0    False             False              False                   True
# 1    False             False              False                  False
# 2    False              True              False                  False
# 3    False              True              False                  False
# 4    False             False              False                  False
# ..     ...               ...                ...                    ...
# 743  False             False              False                  False
# 744  False             False              False                  False
# 745  False             False              False                  False
# 746  False             False              False                  False
# 747  False             False              False                  False
#
#      Time (months)  whether he/she donated blood in March 2007
# 0            False                                       False
# 1            False                                       False
# 2            False                                       False
# 3            False                                       False
# 4            False                                       False
# ..             ...                                         ...
# 743          False                                       False
# 744          False                                       False
# 745          False                                       False
# 746          False                                       False
# 747          False                                       False
#
# [748 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# 0                                             0
# Recency (months)                              2
# Frequency (times)                             0
# Monetary (c.c. blood)                         1
# Time (months)                                 0
# whether he/she donated blood in March 2007    0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 3

# %%
df.notnull()
# Out:
#         0  Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0    True              True               True                  False
# 1    True              True               True                   True
# 2    True             False               True                   True
# 3    True             False               True                   True
# 4    True              True               True                   True
# ..    ...               ...                ...                    ...
# 743  True              True               True                   True
# 744  True              True               True                   True
# 745  True              True               True                   True
# 746  True              True               True                   True
# 747  True              True               True                   True
#
#      Time (months)  whether he/she donated blood in March 2007
# 0             True                                        True
# 1             True                                        True
# 2             True                                        True
# 3             True                                        True
# 4             True                                        True
# ..             ...                                         ...
# 743           True                                        True
# 744           True                                        True
# 745           True                                        True
# 746           True                                        True
# 747           True                                        True
#
# [748 rows x 6 columns]

# %%
df.notnull().sum()
# Out:
# 0                                             748
# Recency (months)                              746
# Frequency (times)                             748
# Monetary (c.c. blood)                         747
# Time (months)                                 748
# whether he/she donated blood in March 2007    748
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# 4485

# %%
# Series 
import numpy as np
sr = pd.Series([1,2,3,np.nan,4,np.NAN])
sr
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    NaN
# dtype: float64

# %%
sr.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
sr.isnull().sum()
# Out:
# 2

# %% [markdown]
# #### dropna

# %%
import pandas as pd

# %%
df = pd.read_csv("simple.csv")
df
# Out:
#    ID     Name    Companies      Profit  Growth
# 0   1     Abhi         Ford   2344231.0     20%
# 1   2      NaN  Rolls Royce  87665443.0     10%
# 2   3      ani     Mercedes         NaN     30%
# 3   4      NaN   Lamborgini  98032732.0     25%
# 4   5  bentley      bentley         NaN  19.80%

# %%
df.dropna()
# Out:
#    ID  Name Companies     Profit Growth
# 0   1  Abhi      Ford  2344231.0    20%

# %%
df.dropna(axis=1)
# axis = 1 means we are going to drop column and axis = 0 means we are going to drop row.
# Default case is also row
# Out:
#    ID    Companies  Growth
# 0   1         Ford     20%
# 1   2  Rolls Royce     10%
# 2   3     Mercedes     30%
# 3   4   Lamborgini     25%
# 4   5      bentley  19.80%

# %%
df.dropna(how='any')
# Out:
#    ID  Name Companies     Profit Growth
# 0   1  Abhi      Ford  2344231.0    20%

# %%
df.dropna(how='any', axis=1)
# Out:
#    ID    Companies  Growth
# 0   1         Ford     20%
# 1   2  Rolls Royce     10%
# 2   3     Mercedes     30%
# 3   4   Lamborgini     25%
# 4   5      bentley  19.80%

# %%
df.dropna(how='all')
# Out:
#    ID     Name    Companies      Profit  Growth
# 0   1     Abhi         Ford   2344231.0     20%
# 1   2      NaN  Rolls Royce  87665443.0     10%
# 2   3      ani     Mercedes         NaN     30%
# 3   4      NaN   Lamborgini  98032732.0     25%
# 4   5  bentley      bentley         NaN  19.80%

# %%
# df.dropna(thresh = 1)
# It will print all rows which have atleast one notnull value.

# %%
df.dropna(subset=['ID'])
# Out:
#    ID     Name    Companies      Profit  Growth
# 0   1     Abhi         Ford   2344231.0     20%
# 1   2      NaN  Rolls Royce  87665443.0     10%
# 2   3      ani     Mercedes         NaN     30%
# 3   4      NaN   Lamborgini  98032732.0     25%
# 4   5  bentley      bentley         NaN  19.80%

# %%
df.dropna(subset=['Growth'])
# Out:
#    ID     Name    Companies      Profit  Growth
# 0   1     Abhi         Ford   2344231.0     20%
# 1   2      NaN  Rolls Royce  87665443.0     10%
# 2   3      ani     Mercedes         NaN     30%
# 3   4      NaN   Lamborgini  98032732.0     25%
# 4   5  bentley      bentley         NaN  19.80%

# %%
df.dropna(subset=['Name'])
# Out:
#    ID     Name Companies     Profit  Growth
# 0   1     Abhi      Ford  2344231.0     20%
# 2   3      ani  Mercedes        NaN     30%
# 4   5  bentley   bentley        NaN  19.80%

# %%
#df.dropna(inplace=True)
#df

# %% [markdown]
# #### fillna()

# %%
dt = pd.read_csv('simple.csv')
dt.head()
# Out:
#    ID     Name    Companies      Profit  Growth
# 0   1     Abhi         Ford   2344231.0     20%
# 1   2      NaN  Rolls Royce  87665443.0     10%
# 2   3      ani     Mercedes         NaN     30%
# 3   4      NaN   Lamborgini  98032732.0     25%
# 4   5  bentley      bentley         NaN  19.80%

# %%
dt.fillna(0)
# Out:
#    ID     Name    Companies      Profit  Growth
# 0   1     Abhi         Ford   2344231.0     20%
# 1   2        0  Rolls Royce  87665443.0     10%
# 2   3      ani     Mercedes         0.0     30%
# 3   4        0   Lamborgini  98032732.0     25%
# 4   5  bentley      bentley         0.0  19.80%

# %%
dt.fillna(2)
# Out:
#    ID     Name    Companies      Profit  Growth
# 0   1     Abhi         Ford   2344231.0     20%
# 1   2        2  Rolls Royce  87665443.0     10%
# 2   3      ani     Mercedes         2.0     30%
# 3   4        2   Lamborgini  98032732.0     25%
# 4   5  bentley      bentley         2.0  19.80%

# %%
dt.fillna({'Name':'Nandu','Profit':0, 'Growth':0})
# Out:
#    ID     Name    Companies      Profit  Growth
# 0   1     Abhi         Ford   2344231.0     20%
# 1   2    Nandu  Rolls Royce  87665443.0     10%
# 2   3      ani     Mercedes         0.0     30%
# 3   4    Nandu   Lamborgini  98032732.0     25%
# 4   5  bentley      bentley         0.0  19.80%

# %%
#dt.fillna(method = 'ffill')
dt.ffill()
# Out:
#    ID     Name    Companies      Profit  Growth
# 0   1     Abhi         Ford   2344231.0     20%
# 1   2     Abhi  Rolls Royce  87665443.0     10%
# 2   3      ani     Mercedes  87665443.0     30%
# 3   4      ani   Lamborgini  98032732.0     25%
# 4   5  bentley      bentley  98032732.0  19.80%

# %%
#dt.fillna(method = 'bfill')
dt.bfill()
# Out:
#    ID     Name    Companies      Profit  Growth
# 0   1     Abhi         Ford   2344231.0     20%
# 1   2      ani  Rolls Royce  87665443.0     10%
# 2   3      ani     Mercedes  98032732.0     30%
# 3   4  bentley   Lamborgini  98032732.0     25%
# 4   5  bentley      bentley         NaN  19.80%

# %%
#dt.fillna(method='ffill',axis=0)
dt.ffill(axis=0)
# Out:
#    ID     Name    Companies      Profit  Growth
# 0   1     Abhi         Ford   2344231.0     20%
# 1   2     Abhi  Rolls Royce  87665443.0     10%
# 2   3      ani     Mercedes  87665443.0     30%
# 3   4      ani   Lamborgini  98032732.0     25%
# 4   5  bentley      bentley  98032732.0  19.80%

# %%
#dt.fillna(method='ffill',axis=1)
dt.ffill(axis=1)
# Out:
#   ID     Name    Companies      Profit  Growth
# 0  1     Abhi         Ford   2344231.0     20%
# 1  2        2  Rolls Royce  87665443.0     10%
# 2  3      ani     Mercedes    Mercedes     30%
# 3  4        4   Lamborgini  98032732.0     25%
# 4  5  bentley      bentley     bentley  19.80%

# %%
dt.fillna(0, limit=1)
# Out:
#    ID     Name    Companies      Profit  Growth
# 0   1     Abhi         Ford   2344231.0     20%
# 1   2        0  Rolls Royce  87665443.0     10%
# 2   3      ani     Mercedes         0.0     30%
# 3   4      NaN   Lamborgini  98032732.0     25%
# 4   5  bentley      bentley         NaN  19.80%

# %%
#dt.fillna(method ='ffill', limit=1)
dt.ffill(limit=1)
# Out:
#    ID     Name    Companies      Profit  Growth
# 0   1     Abhi         Ford   2344231.0     20%
# 1   2     Abhi  Rolls Royce  87665443.0     10%
# 2   3      ani     Mercedes  87665443.0     30%
# 3   4      ani   Lamborgini  98032732.0     25%
# 4   5  bentley      bentley  98032732.0  19.80%

# %% [markdown]
# #### replace()

# %%
y = pd.read_csv('simple.csv')
y.head()
# Out:
#    ID     Name    Companies      Profit  Growth
# 0   1     Abhi         Ford   2344231.0     20%
# 1   2      NaN  Rolls Royce  87665443.0     10%
# 2   3      ani     Mercedes         NaN     30%
# 3   4      NaN   Lamborgini  98032732.0     25%
# 4   5  bentley      bentley         NaN  19.80%

# %%
# y.replace(to_replace='bentley',value='battery')
y.replace('bentley','battery')
# Out:
#    ID     Name    Companies      Profit  Growth
# 0   1     Abhi         Ford   2344231.0     20%
# 1   2      NaN  Rolls Royce  87665443.0     10%
# 2   3      ani     Mercedes         NaN     30%
# 3   4      NaN   Lamborgini  98032732.0     25%
# 4   5  battery      battery         NaN  19.80%

# %%
y.replace('Ford','Nissan')
# Out:
#    ID     Name    Companies      Profit  Growth
# 0   1     Abhi       Nissan   2344231.0     20%
# 1   2      NaN  Rolls Royce  87665443.0     10%
# 2   3      ani     Mercedes         NaN     30%
# 3   4      NaN   Lamborgini  98032732.0     25%
# 4   5  bentley      bentley         NaN  19.80%

# %%
dt.replace([1,2,3,4,5],[9,8,7,6,5])
# Out:
#    ID     Name    Companies      Profit  Growth
# 0   9     Abhi         Ford   2344231.0     20%
# 1   8      NaN  Rolls Royce  87665443.0     10%
# 2   7      ani     Mercedes         NaN     30%
# 3   6      NaN   Lamborgini  98032732.0     25%
# 4   5  bentley      bentley         NaN  19.80%

# %%
dt.replace({'Companies':['Rolls Royce','bentley','Lamborgini']}, 'none')
# Out:
#    ID     Name Companies      Profit  Growth
# 0   1     Abhi      Ford   2344231.0     20%
# 1   2      NaN      none  87665443.0     10%
# 2   3      ani  Mercedes         NaN     30%
# 3   4      NaN      none  98032732.0     25%
# 4   5  bentley      none         NaN  19.80%

# %%
dt.replace('[A-Za-z]',0,regex=True)
# Out:
# C:\Users\mahor\AppData\Local\Temp\ipykernel_18540\2389963177.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dt.replace('[A-Za-z]',0,regex=True)
#    ID  Name  Companies      Profit  Growth
# 0   1   0.0          0   2344231.0     20%
# 1   2   NaN          0  87665443.0     10%
# 2   3   0.0          0         NaN     30%
# 3   4   NaN          0  98032732.0     25%
# 4   5   0.0          0         NaN  19.80%

# %% [markdown]
# #### interpolate()

# %%
# Pandas interpolate function is basically used to fill nan values in dataframe or series.
# It is very powerful function and uses various interpolation techniques.

# %%
import pandas as pd

# %%
y1= pd.read_csv('stud.csv')
y1
# Out:
#          Date  Student ID  Class Section  Study hrs  Percentage
# 0  01-07-2019        1001     10       A        5.0        77.0
# 1  02-07-2019        1002     11     NaN        6.0        76.0
# 2  03-07-2019        1003     12     NaN        4.0        58.0
# 3  04-07-2019        1004      9     NaN        8.0        89.0
# 4  05-07-2019        1005     10       B        7.0         NaN
# 5  06-07-2019        1006      9       A       10.0        89.0
# 6  07-07-2019        1007     12     NaN        NaN        82.0
# 7  08-07-2019        1008     11       B        6.0         NaN
# 8  09-07-2019        1009     12       B        NaN        90.0

# %%
y1.infer_objects(copy=False)
y1.interpolate()
# Out:
# C:\Users\mahor\AppData\Local\Temp\ipykernel_18540\1863674940.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   y1.interpolate()
#          Date  Student ID  Class Section  Study hrs  Percentage
# 0  01-07-2019        1001     10       A        5.0        77.0
# 1  02-07-2019        1002     11     NaN        6.0        76.0
# 2  03-07-2019        1003     12     NaN        4.0        58.0
# 3  04-07-2019        1004      9     NaN        8.0        89.0
# 4  05-07-2019        1005     10       B        7.0        89.0
# 5  06-07-2019        1006      9       A       10.0        89.0
# 6  07-07-2019        1007     12     NaN        8.0        82.0
# 7  08-07-2019        1008     11       B        6.0        86.0
# 8  09-07-2019        1009     12       B        6.0        90.0

# %%
y1.interpolate(method ='linear')
# Out:
# C:\Users\mahor\AppData\Local\Temp\ipykernel_18540\2630124649.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   y1.interpolate(method ='linear')
#          Date  Student ID  Class Section  Study hrs  Percentage
# 0  01-07-2019        1001     10       A        5.0        77.0
# 1  02-07-2019        1002     11     NaN        6.0        76.0
# 2  03-07-2019        1003     12     NaN        4.0        58.0
# 3  04-07-2019        1004      9     NaN        8.0        89.0
# 4  05-07-2019        1005     10       B        7.0        89.0
# 5  06-07-2019        1006      9       A       10.0        89.0
# 6  07-07-2019        1007     12     NaN        8.0        82.0
# 7  08-07-2019        1008     11       B        6.0        86.0
# 8  09-07-2019        1009     12       B        6.0        90.0

# %%
# y1.interpolate(method='time')

# %%
type(y1.Date[0])
# Out:
# str

# %%
y1=pd.read_csv('stud.csv',parse_dates=['Date'])

# %%
y1
# Out:
#         Date  Student ID  Class Section  Study hrs  Percentage
# 0 2019-01-07        1001     10       A        5.0        77.0
# 1 2019-02-07        1002     11     NaN        6.0        76.0
# 2 2019-03-07        1003     12     NaN        4.0        58.0
# 3 2019-04-07        1004      9     NaN        8.0        89.0
# 4 2019-05-07        1005     10       B        7.0         NaN
# 5 2019-06-07        1006      9       A       10.0        89.0
# 6 2019-07-07        1007     12     NaN        NaN        82.0
# 7 2019-08-07        1008     11       B        6.0         NaN
# 8 2019-09-07        1009     12       B        NaN        90.0

# %%
type(y1.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
y1=pd.read_csv('stud.csv',parse_dates=['Date'],index_col='Date')
y1
# Out:
#             Student ID  Class Section  Study hrs  Percentage
# Date
# 2019-01-07        1001     10       A        5.0        77.0
# 2019-02-07        1002     11     NaN        6.0        76.0
# 2019-03-07        1003     12     NaN        4.0        58.0
# 2019-04-07        1004      9     NaN        8.0        89.0
# 2019-05-07        1005     10       B        7.0         NaN
# 2019-06-07        1006      9       A       10.0        89.0
# 2019-07-07        1007     12     NaN        NaN        82.0
# 2019-08-07        1008     11       B        6.0         NaN
# 2019-09-07        1009     12       B        NaN        90.0

# %%
y1.interpolate(method='time')
# Out:
# C:\Users\mahor\AppData\Local\Temp\ipykernel_18540\4122036815.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   y1.interpolate(method='time')
#             Student ID  Class Section  Study hrs  Percentage
# Date
# 2019-01-07        1001     10       A   5.000000        77.0
# 2019-02-07        1002     11     NaN   6.000000        76.0
# 2019-03-07        1003     12     NaN   4.000000        58.0
# 2019-04-07        1004      9     NaN   8.000000        89.0
# 2019-05-07        1005     10       B   7.000000        89.0
# 2019-06-07        1006      9       A  10.000000        89.0
# 2019-07-07        1007     12     NaN   8.032787        82.0
# 2019-08-07        1008     11       B   6.000000        86.0
# 2019-09-07        1009     12       B   6.000000        90.0

# %%
y1.interpolate(method='index')
# Out:
# C:\Users\mahor\AppData\Local\Temp\ipykernel_18540\3622211553.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   y1.interpolate(method='index')
#             Student ID  Class Section  Study hrs  Percentage
# Date
# 2019-01-07        1001     10       A   5.000000        77.0
# 2019-02-07        1002     11     NaN   6.000000        76.0
# 2019-03-07        1003     12     NaN   4.000000        58.0
# 2019-04-07        1004      9     NaN   8.000000        89.0
# 2019-05-07        1005     10       B   7.000000        89.0
# 2019-06-07        1006      9       A  10.000000        89.0
# 2019-07-07        1007     12     NaN   8.032787        82.0
# 2019-08-07        1008     11       B   6.000000        86.0
# 2019-09-07        1009     12       B   6.000000        90.0

# %%
y1.interpolate(method= 'polynomial', order=1)
# Out:
# C:\Users\mahor\AppData\Local\Temp\ipykernel_18540\598058398.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   y1.interpolate(method= 'polynomial', order=1)
#             Student ID  Class Section  Study hrs  Percentage
# Date
# 2019-01-07        1001     10       A   5.000000        77.0
# 2019-02-07        1002     11     NaN   6.000000        76.0
# 2019-03-07        1003     12     NaN   4.000000        58.0
# 2019-04-07        1004      9     NaN   8.000000        89.0
# 2019-05-07        1005     10       B   7.000000        89.0
# 2019-06-07        1006      9       A  10.000000        89.0
# 2019-07-07        1007     12     NaN   8.032787        82.0
# 2019-08-07        1008     11       B   6.000000        86.0
# 2019-09-07        1009     12       B        NaN        90.0

# %%
y1.interpolate()
# For axis =1 means filling nan values row by row the datatype should be same.
# limit is used when we want to fill specific number of missing values.
# Out:
# C:\Users\mahor\AppData\Local\Temp\ipykernel_18540\1198031433.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   y1.interpolate()
#             Student ID  Class Section  Study hrs  Percentage
# Date
# 2019-01-07        1001     10       A        5.0        77.0
# 2019-02-07        1002     11     NaN        6.0        76.0
# 2019-03-07        1003     12     NaN        4.0        58.0
# 2019-04-07        1004      9     NaN        8.0        89.0
# 2019-05-07        1005     10       B        7.0        89.0
# 2019-06-07        1006      9       A       10.0        89.0
# 2019-07-07        1007     12     NaN        8.0        82.0
# 2019-08-07        1008     11       B        6.0        86.0
# 2019-09-07        1009     12       B        6.0        90.0

# %%
y1.interpolate(limit=1)
# Out:
# C:\Users\mahor\AppData\Local\Temp\ipykernel_18540\727434643.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   y1.interpolate(limit=1)
#             Student ID  Class Section  Study hrs  Percentage
# Date
# 2019-01-07        1001     10       A        5.0        77.0
# 2019-02-07        1002     11     NaN        6.0        76.0
# 2019-03-07        1003     12     NaN        4.0        58.0
# 2019-04-07        1004      9     NaN        8.0        89.0
# 2019-05-07        1005     10       B        7.0        89.0
# 2019-06-07        1006      9       A       10.0        89.0
# 2019-07-07        1007     12     NaN        8.0        82.0
# 2019-08-07        1008     11       B        6.0        86.0
# 2019-09-07        1009     12       B        6.0        90.0

# %%
y1=pd.read_csv('stud.csv',parse_dates=['Date'],index_col='Date')
y1
# Out:
#             Student ID  Class Section  Study hrs  Percentage
# Date
# 2019-01-07        1001     10       A        5.0        77.0
# 2019-02-07        1002     11     NaN        6.0        76.0
# 2019-03-07        1003     12     NaN        4.0        58.0
# 2019-04-07        1004      9     NaN        8.0        89.0
# 2019-05-07        1005     10       B        7.0         NaN
# 2019-06-07        1006      9       A       10.0        89.0
# 2019-07-07        1007     12     NaN        NaN        82.0
# 2019-08-07        1008     11       B        6.0         NaN
# 2019-09-07        1009     12       B        NaN        90.0

# %%
y1.interpolate(limit =1 , limit_direction='both')
# Out:
# C:\Users\mahor\AppData\Local\Temp\ipykernel_18540\368468568.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   y1.interpolate(limit =1 , limit_direction='both')
#             Student ID  Class Section  Study hrs  Percentage
# Date
# 2019-01-07        1001     10       A        5.0        77.0
# 2019-02-07        1002     11     NaN        6.0        76.0
# 2019-03-07        1003     12     NaN        4.0        58.0
# 2019-04-07        1004      9     NaN        8.0        89.0
# 2019-05-07        1005     10       B        7.0        89.0
# 2019-06-07        1006      9       A       10.0        89.0
# 2019-07-07        1007     12     NaN        8.0        82.0
# 2019-08-07        1008     11       B        6.0        86.0
# 2019-09-07        1009     12       B        6.0        90.0

# %%
y1
# Out:
#             Student ID  Class Section  Study hrs  Percentage
# Date
# 2019-01-07        1001     10       A        5.0        77.0
# 2019-02-07        1002     11     NaN        6.0        76.0
# 2019-03-07        1003     12     NaN        4.0        58.0
# 2019-04-07        1004      9     NaN        8.0        89.0
# 2019-05-07        1005     10       B        7.0         NaN
# 2019-06-07        1006      9       A       10.0        89.0
# 2019-07-07        1007     12     NaN        NaN        82.0
# 2019-08-07        1008     11       B        6.0         NaN
# 2019-09-07        1009     12       B        NaN        90.0

# %%
y1.interpolate(limit_area='inside')
# Out:
# C:\Users\mahor\AppData\Local\Temp\ipykernel_18540\4029386824.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   y1.interpolate(limit_area='inside')
#             Student ID  Class Section  Study hrs  Percentage
# Date
# 2019-01-07        1001     10       A        5.0        77.0
# 2019-02-07        1002     11     NaN        6.0        76.0
# 2019-03-07        1003     12     NaN        4.0        58.0
# 2019-04-07        1004      9     NaN        8.0        89.0
# 2019-05-07        1005     10       B        7.0        89.0
# 2019-06-07        1006      9       A       10.0        89.0
# 2019-07-07        1007     12     NaN        8.0        82.0
# 2019-08-07        1008     11       B        6.0        86.0
# 2019-09-07        1009     12       B        NaN        90.0

# %%
y1.interpolate(limit_area='outside')
# Out:
# C:\Users\mahor\AppData\Local\Temp\ipykernel_18540\1447686373.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   y1.interpolate(limit_area='outside')
#             Student ID  Class Section  Study hrs  Percentage
# Date
# 2019-01-07        1001     10       A        5.0        77.0
# 2019-02-07        1002     11     NaN        6.0        76.0
# 2019-03-07        1003     12     NaN        4.0        58.0
# 2019-04-07        1004      9     NaN        8.0        89.0
# 2019-05-07        1005     10       B        7.0         NaN
# 2019-06-07        1006      9       A       10.0        89.0
# 2019-07-07        1007     12     NaN        NaN        82.0
# 2019-08-07        1008     11       B        6.0         NaN
# 2019-09-07        1009     12       B        6.0        90.0

# %%
y1.interpolate(inplace=True)
y1
# Out:
# C:\Users\mahor\AppData\Local\Temp\ipykernel_18540\1441990515.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   y1.interpolate(inplace=True)
#             Student ID  Class Section  Study hrs  Percentage
# Date
# 2019-01-07        1001     10       A        5.0        77.0
# 2019-02-07        1002     11     NaN        6.0        76.0
# 2019-03-07        1003     12     NaN        4.0        58.0
# 2019-04-07        1004      9     NaN        8.0        89.0
# 2019-05-07        1005     10       B        7.0        89.0
# 2019-06-07        1006      9       A       10.0        89.0
# 2019-07-07        1007     12     NaN        8.0        82.0
# 2019-08-07        1008     11       B        6.0        86.0
# 2019-09-07        1009     12       B        6.0        90.0

# %% [markdown]
# ### Pandas loc and iloc

# %%
# Access a group of rows and columns by label(s) or a boolean array.
# Syntax: DataFrame.loc[]

# %%
import pandas as pd

# %%
df=pd.read_csv('stud.csv')
df
# Out:
#          Date  Student ID  Class Section  Study hrs  Percentage
# 0  01-07-2019        1001     10       A        5.0        77.0
# 1  02-07-2019        1002     11     NaN        6.0        76.0
# 2  03-07-2019        1003     12     NaN        4.0        58.0
# 3  04-07-2019        1004      9     NaN        8.0        89.0
# 4  05-07-2019        1005     10       B        7.0         NaN
# 5  06-07-2019        1006      9       A       10.0        89.0
# 6  07-07-2019        1007     12     NaN        NaN        82.0
# 7  08-07-2019        1008     11       B        6.0         NaN
# 8  09-07-2019        1009     12       B        NaN        90.0

# %%
df.loc[0]
# Out:
# Date          01-07-2019
# Student ID          1001
# Class                 10
# Section                A
# Study hrs            5.0
# Percentage          77.0
# Name: 0, dtype: object

# %%
df.loc[4]
# Out:
# Date          05-07-2019
# Student ID          1005
# Class                 10
# Section                B
# Study hrs            7.0
# Percentage           NaN
# Name: 4, dtype: object

# %%
df.loc[[0,1]]
# Out:
#          Date  Student ID  Class Section  Study hrs  Percentage
# 0  01-07-2019        1001     10       A        5.0        77.0
# 1  02-07-2019        1002     11     NaN        6.0        76.0

# %%
df.loc[3,'Class']
# Out:
# 9

# %%
df.loc[0:3,'Class']
# Out:
# 0    10
# 1    11
# 2    12
# 3     9
# Name: Class, dtype: int64

# %%
df.loc[0:3,'Percentage']
# Out:
# 0    77.0
# 1    76.0
# 2    58.0
# 3    89.0
# Name: Percentage, dtype: float64

# %%
df.loc[[False,False,True,False,True,False,False,True,True]]
# Out:
#          Date  Student ID  Class Section  Study hrs  Percentage
# 2  03-07-2019        1003     12     NaN        4.0        58.0
# 4  05-07-2019        1005     10       B        7.0         NaN
# 7  08-07-2019        1008     11       B        6.0         NaN
# 8  09-07-2019        1009     12       B        NaN        90.0

# %%
df.loc[[False,False,True,True,True,False,False,True,True]]
# Out:
#          Date  Student ID  Class Section  Study hrs  Percentage
# 2  03-07-2019        1003     12     NaN        4.0        58.0
# 3  04-07-2019        1004      9     NaN        8.0        89.0
# 4  05-07-2019        1005     10       B        7.0         NaN
# 7  08-07-2019        1008     11       B        6.0         NaN
# 8  09-07-2019        1009     12       B        NaN        90.0

# %%
df.loc[[False,False,False,False,True,False,False,True,False]]
# Out:
#          Date  Student ID  Class Section  Study hrs  Percentage
# 4  05-07-2019        1005     10       B        7.0         NaN
# 7  08-07-2019        1008     11       B        6.0         NaN

# %%
df.loc[df['Class']<11,['Percentage']]
# Out:
#    Percentage
# 0        77.0
# 3        89.0
# 4         NaN
# 5        89.0

# %%
## Integer location-based indexing
## Syntax: DataFrame.iloc[]

# %%
 df.iloc[0]
# Out:
# Date          01-07-2019
# Student ID          1001
# Class                 10
# Section                A
# Study hrs            5.0
# Percentage          77.0
# Name: 0, dtype: object

# %%
 df.iloc[[0]]
# Out:
#          Date  Student ID  Class Section  Study hrs  Percentage
# 0  01-07-2019        1001     10       A        5.0        77.0

# %% [markdown]
# ### Pandas GROUPBY

# %%
# Pandas groupby function is used to split the data into groups based on some criteria.
# Syntax: Dataframe.groupby()
# Groupby operation involves one of the following operations on the original object.
# - Splitting the objects
# -Applying a function
# - Combining the result

# %%
import pandas as pd

# %%
df=pd.read_csv('stud.csv')
df
# Out:
#          Date  Student ID  Class Section  Study hrs  Percentage
# 0  01-07-2019        1001     10       A        5.0        77.0
# 1  02-07-2019        1002     11     NaN        6.0        76.0
# 2  03-07-2019        1003     12     NaN        4.0        58.0
# 3  04-07-2019        1004      9     NaN        8.0        89.0
# 4  05-07-2019        1005     10       B        7.0         NaN
# 5  06-07-2019        1006      9       A       10.0        89.0
# 6  07-07-2019        1007     12     NaN        NaN        82.0
# 7  08-07-2019        1008     11       B        6.0         NaN
# 8  09-07-2019        1009     12       B        NaN        90.0

# %%
gr1=df.groupby(by= 'Section')
gr1

# %%
gr1.groups
# Out:
# {'A': [0, 5], 'B': [4, 7, 8]}

# %%
df.groupby(['Section','Class']).groups
# Out:
# {('A', 9): [5], ('A', 10): [0], ('B', 10): [4], ('B', 11): [7], ('B', 12): [8], (nan, 9): [3], (nan, 11): [1], (nan, 12): [2, 6]}

# %%
for Section, df_1 in gr1:
    print(Section)
    print(df_1)
# Out:
# A
#          Date  Student ID  Class Section  Study hrs  Percentage
# 0  01-07-2019        1001     10       A        5.0        77.0
# 5  06-07-2019        1006      9       A       10.0        89.0
# B
#          Date  Student ID  Class Section  Study hrs  Percentage
# 4  05-07-2019        1005     10       B        7.0         NaN
# 7  08-07-2019        1008     11       B        6.0         NaN
# 8  09-07-2019        1009     12       B        NaN        90.0

# %%
gr3= df.groupby('Class').get_group(10)
gr3
# Out:
#          Date  Student ID  Class Section  Study hrs  Percentage
# 0  01-07-2019        1001     10       A        5.0        77.0
# 4  05-07-2019        1005     10       B        7.0         NaN

# %%
gr1.sum()
# Out:
#                                    Date  Student ID  Class  Study hrs  \
# Section
# A                  01-07-201906-07-2019        2007     19       15.0
# B        05-07-201908-07-201909-07-2019        3022     33       13.0
#
#          Percentage
# Section
# A             166.0
# B              90.0

# %%
gr1.describe()
# Out:
#         Student ID                                                           \
#              count         mean       std     min      25%     50%      75%
# Section
# A              2.0  1003.500000  3.535534  1001.0  1002.25  1003.5  1004.75
# B              3.0  1007.333333  2.081666  1005.0  1006.50  1008.0  1008.50
#
#                 Class        ... Study hrs       Percentage                  \
#             max count  mean  ...       75%   max      count  mean       std
# Section                      ...
# A        1006.0   2.0   9.5  ...      8.75  10.0        2.0  83.0  8.485281
# B        1009.0   3.0  11.0  ...      6.75   7.0        1.0  90.0       NaN
#
#
#           min   25%   50%   75%   max
# Section
# A        77.0  80.0  83.0  86.0  89.0
# B        90.0  90.0  90.0  90.0  90.0
#
# [2 rows x 32 columns]

# %%
gr1.agg(['sum','max','min'])
# Out:
#                                    Date                         Student ID  \
#                                     sum         max         min        sum
# Section
# A                  01-07-201906-07-2019  06-07-2019  01-07-2019       2007
# B        05-07-201908-07-201909-07-2019  09-07-2019  05-07-2019       3022
#
#                     Class         Study hrs            Percentage
#           max   min   sum max min       sum   max  min        sum   max   min
# Section
# A        1006  1001    19  10   9      15.0  10.0  5.0      166.0  89.0  77.0
# B        1009  1005    33  12  10      13.0   7.0  6.0       90.0  90.0  90.0

# %% [markdown]
# ### Pandas merging function

# %%
# Pandas merge function connects columns or indexes in dataframe based on one or more keys.

# %%
import pandas as pd

# %%
mr1= pd.DataFrame({'ID':[1,2,3,4],'Class':[5,6,7,8]})
mr1
# Out:
#    ID  Class
# 0   1      5
# 1   2      6
# 2   3      7
# 3   4      8

# %%
mr2=pd.DataFrame({'ID':[1,2,3,4],'Name':['A','B','C','D']})
mr2
# Out:
#    ID Name
# 0   1    A
# 1   2    B
# 2   3    C
# 3   4    D

# %%
pd.merge(mr1,mr2)
# Out:
#    ID  Class Name
# 0   1      5    A
# 1   2      6    B
# 2   3      7    C
# 3   4      8    D

# %%
pd.merge(mr1,mr2,on='ID')
# Out:
#    ID  Class Name
# 0   1      5    A
# 1   2      6    B
# 2   3      7    C
# 3   4      8    D
